# %%
from PIL import Image as PIL_Image

orig_img_path = '/home/xilinx/jupyter_notebooks/examples/data/webcam.jpg'
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2> /dev/null

img = PIL_Image.open(orig_img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x288 at 0xB6430250>

# %%
bw_img = img.convert("L")
bw_img
# Out:
# <PIL.Image.Image image mode=L size=352x288 at 0xB4441470>

# %%
rot_img = img.rotate(45)
rot_img
# Out:
# <PIL.Image.Image image mode=RGB size=352x288 at 0xB0E74BF0>

# %%
img = PIL_Image.open(orig_img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x288 at 0xB0E74E30>

# %%
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2> /dev/null
img = PIL_Image.open(orig_img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x288 at 0xB4441490>
